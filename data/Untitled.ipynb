# %%
import json
import pandas as pd

# %%
f = open("all_url_info_dict.json","r")
all_url_info = json.loads(f.read())
f.close()

# %%
b = [url.split('&')[0] for url in list(all_url_info.keys())[4:]]

# %%
list(set(b))
# Out:
# ['https://www.ulta.com/skin-care-treatment-serums-body-treatments?N=7ytwqk',
#  'https://www.ulta.com/bath-body-bath-shower-shower-gel-body-wash?N=26uz',
#  'https://www.ulta.com/nail-polish?N=278s',
#  'https://www.ulta.com/skin-care-cleansers-makeup-remover?N=27gx',
#  'https://www.ulta.com/hair-gifts-value-sets?N=277l',
#  'https://www.ulta.com/makeup-eyes-mascara?N=26yg',
#  'https://www.ulta.com/bath-body-self-care-wellness-down-there-care?N=8xc9b0',
#  'https://www.ulta.com/bath-body-accessories-bath-sponges-gloves-brushes?N=27i9',
#  'https://www.ulta.com/men-skin-care?N=27ck',
#  'https://www.ulta.com/makeup-face-foundation?N=26y5',
#  'https://www.ulta.com/hair-styling-products?N=26xf',
#  'https://www.ulta.com/fragrance-gift-sets-perfume-gift-sets?N=27io',
#  'https://www.ulta.com/mens-fragrance-aftershave?N=c0fphe',
#  'https://www.ulta.com/makeup-lips?N=26yq',
#  'https://www.ulta.com/skin-care-eye-treatments-eye-serums?N=27hl',
# ...
